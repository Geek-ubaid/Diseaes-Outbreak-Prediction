# %%
import warnings
warnings.filterwarnings("ignore") 
import pandas as pd
import calendar
import numpy as np
import pickle

# %%
# function to extract month and year from the dataset

def week2month(hep):
    hep['LastDayWeek'] = pd.to_datetime((hep['week']-1).astype(str) + "6", format="%Y%U%w")
    hep['MonthMax'] = pd.DatetimeIndex(hep['LastDayWeek']).month
    hep['Year'] = pd.DatetimeIndex(hep['LastDayWeek']).year
    hep['MonthName'] = [calendar.month_name[i] for i in hep.MonthMax]
    return hep

# %%
# function to load the dataset
def get_input_transform(file_):
    return week2month(pd.read_csv(file_))

# %%
# load the dataset from Kaggle
hep = get_input_transform('data/hepatitis.csv')
mea = get_input_transform('data/measles.csv')
mum = get_input_transform('data/mumps.csv')
per = get_input_transform('data/pertussis.csv')
pol = get_input_transform('data/polio.csv')
rub = get_input_transform('data/rubella.csv')
sma = get_input_transform('data/smallpox.csv')

# %%
train_data = hep
for i in [mea,mum,per,pol,rub,sma]:
    train_data = train_data.append(i)
train_data = train_data.loc[(train_data['Year'] >= 1960) & (train_data['Year'] <=2011)]
# examine the dataset 
train_data.head()
# Out:
#      week state  state_name      disease cases  incidence_per_capita  \
# 0  196601    AL     ALABAMA  HEPATITIS A     5                  0.14
# 1  196601    AR    ARKANSAS  HEPATITIS A    11                  0.58
# 2  196601    AZ     ARIZONA  HEPATITIS A     6                  0.37
# 3  196601    CA  CALIFORNIA  HEPATITIS A    89                  0.47
# 4  196601    CO    COLORADO  HEPATITIS A     1                  0.05
#
#   LastDayWeek  MonthMax  Year MonthName
# 0  1966-01-01         1  1966   January
# 1  1966-01-01         1  1966   January
# 2  1966-01-01         1  1966   January
# 3  1966-01-01         1  1966   January
# 4  1966-01-01         1  1966   January

# %%
# some data discrepancies must be resolved (issues like \\N )
train_data.cases = train_data.cases.astype('str')
train_data_bad = train_data[train_data.cases==train_data.cases.max()]
ind = list(train_data_bad.index)
train_data = train_data.drop(train_data.index[ind])

# %%
# will be using visulisation.csv for our visualization purposes later# will b 

train_data.to_csv('for_visulisation.csv')

# %%
train_data.cases = train_data.cases.astype(int)

# %%
# examining the characteristics of the dataset
train_data.describe()
# Out:
#                 week          cases  incidence_per_capita       MonthMax  \
# count  361935.000000  361935.000000         361935.000000  361935.000000
# mean   198461.036059      15.238026              0.429124       6.933999
# std      1330.980200      84.493216              2.233045       3.279924
# min    196001.000000       0.000000              0.000000       1.000000
# 25%    197349.000000       0.000000              0.000000       4.000000
# 50%    198342.000000       1.000000              0.030000       7.000000
# 75%    199524.000000       7.000000              0.190000      10.000000
# max    201152.000000    7101.000000            209.160000      12.000000
#
#                 Year
# count  361935.000000
# mean     1984.325221
# std        13.298776
# min      1960.000000
# 25%      1973.000000
# 50%      1983.000000
# 75%      1995.000000
# max      2011.000000

# %%
# converting non-numerical data to lowercase (to keep consistencies over all future datasets included)

train_data.state_name = [i.lower() for i in train_data.state_name]

# %% [markdown]
# # Feature additions
# Adding features like
# - Average temperature
# - Average precipitation
# - Average population
# - Polution standards
# #### These features have certain effect on the contagious disease spread

# %%
join_tavg = pd.read_excel('TemperaturesByState.xlsx', index_col= 0)
# make sure non-nmerical data in lowercase format

join_tavg['Date'] = pd.to_datetime(join_tavg['Date'],format = "%Y%U%w")
join_tavg['Year'] = pd.DatetimeIndex(join_tavg['Date']).year
join_tavg['Month'] = pd.DatetimeIndex(join_tavg['Date']).month
join_tavg = join_tavg.loc[(join_tavg['Year'] >= 1960) & (join_tavg['Year'] <=2011)]
join_tavg.State = [i.lower() for i in join_tavg.State]
join_tavg = join_tavg.drop('Country',axis=1)
join_tavg.head()

# convert the column names for tavg dataset to match column names to our primary dataset
join_tavg.columns = [ 'LastDayWeek','t_avg', 'tavg_anomaly', 'state_name','Year','MonthMax']

# %%
# examine the dataset

print (join_tavg.shape)
join_tavg.head()
# Out:
# (31824, 6)
#       LastDayWeek    t_avg  tavg_anomaly state_name  Year  MonthMax
# index
# 0      1960-01-01  44.9114         0.219    alabama  1960         1
# 0      1960-01-02  44.6396         0.221    alabama  1960         1
# 0      1960-01-03  45.7358         0.099    alabama  1960         1
# 0      1960-01-04  64.1444         0.239    alabama  1960         1
# 0      1960-01-05  68.1278         0.305    alabama  1960         1

# %%
# join the avg temperature dataset with our priary dataset over common columns

result = pd.merge(train_data, join_tavg, on=['LastDayWeek','Year','state_name','MonthMax'])

# %%
#examining the primary dataset

print (result.shape)
result.to_csv('for_temp_visualization.csv')
train_data = result # make this your current working dataframe 
result.head()
# Out:
# (5130, 12)
#      week state state_name      disease  cases  incidence_per_capita  \
# 0  196601    AL    alabama  HEPATITIS A      5                  0.14
# 1  196601    AL    alabama      RUBELLA      7                  0.20
# 2  196601    AR   arkansas  HEPATITIS A     11                  0.58
# 3  196601    AR   arkansas      MEASLES      2                  0.11
# 4  196601    AZ    arizona  HEPATITIS A      6                  0.37
#
#   LastDayWeek  MonthMax  Year MonthName    t_avg  tavg_anomaly
# 0  1966-01-01         1  1966   January  40.4798         0.235
# 1  1966-01-01         1  1966   January  40.4798         0.235
# 2  1966-01-01         1  1966   January  35.2310         0.225
# 3  1966-01-01         1  1966   January  35.2310         0.225
# 4  1966-01-01         1  1966   January  37.9076         0.285

# %%
# examining the primary dataset now
train_data.head()
# Out:
#      week state state_name      disease  cases  incidence_per_capita  \
# 0  196601    AL    alabama  HEPATITIS A      5                  0.14
# 1  196601    AL    alabama      RUBELLA      7                  0.20
# 2  196601    AR   arkansas  HEPATITIS A     11                  0.58
# 3  196601    AR   arkansas      MEASLES      2                  0.11
# 4  196601    AZ    arizona  HEPATITIS A      6                  0.37
#
#   LastDayWeek  MonthMax  Year MonthName    t_avg  tavg_anomaly
# 0  1966-01-01         1  1966   January  40.4798         0.235
# 1  1966-01-01         1  1966   January  40.4798         0.235
# 2  1966-01-01         1  1966   January  35.2310         0.225
# 3  1966-01-01         1  1966   January  35.2310         0.225
# 4  1966-01-01         1  1966   January  37.9076         0.285

# %%
## Normalize the statistical data

from sklearn.preprocessing import MinMaxScaler as mm

scaler = mm()

# avg temp deviations
scaler.fit(train_data['tavg_anomaly'].reshape(-1,1))
train_data['tavg_anomaly'] = scaler.transform(train_data['tavg_anomaly'].reshape(-1,1))

# avg temp
scaler.fit(train_data['t_avg'].reshape(-1,1))
train_data['t_avg'] = scaler.transform(train_data['t_avg'].reshape(-1,1))

# %%
# examining the main dataset 

train_data.head()
# Out:
#      week state state_name      disease  cases  incidence_per_capita  \
# 0  196601    AL    alabama  HEPATITIS A      5                  0.14
# 1  196601    AL    alabama      RUBELLA      7                  0.20
# 2  196601    AR   arkansas  HEPATITIS A     11                  0.58
# 3  196601    AR   arkansas      MEASLES      2                  0.11
# 4  196601    AZ    arizona  HEPATITIS A      6                  0.37
#
#   LastDayWeek  MonthMax  Year MonthName     t_avg  tavg_anomaly
# 0  1966-01-01         1  1966   January  0.536052      0.235911
# 1  1966-01-01         1  1966   January  0.536052      0.235911
# 2  1966-01-01         1  1966   January  0.482511      0.222805
# 3  1966-01-01         1  1966   January  0.482511      0.222805
# 4  1966-01-01         1  1966   January  0.509814      0.301442

# %%
# save this primary dataset for future purposes

result.to_csv('result.csv',index=False)

# %%
# save the dataset in current working dataframe# save t 
train_data = result

# %%
# load this dataset for future purposes
'''
uncomment the line below when needed,
no need to perform above steps once you reach this step

'''

#train_data = pd.read_csv('result.csv')
# Out:
# '\nuncomment the line below when needed,\nno need to perform above steps once you reach this step\n\n'

# %%
# load the working dataset for future purposes (no need to do the above steps)

train_data = pd.read_csv('result.csv')

# %%
# examining the dataset 
train_data.head()
# Out:
#      week state state_name      disease  cases  incidence_per_capita  \
# 0  196601    AL    alabama  HEPATITIS A      5                  0.14
# 1  196601    AL    alabama      RUBELLA      7                  0.20
# 2  196601    AR   arkansas  HEPATITIS A     11                  0.58
# 3  196601    AR   arkansas      MEASLES      2                  0.11
# 4  196601    AZ    arizona  HEPATITIS A      6                  0.37
#
#   LastDayWeek  MonthMax  Year MonthName     t_avg  tavg_anomaly
# 0  1966-01-01         1  1966   January  0.536052      0.235911
# 1  1966-01-01         1  1966   January  0.536052      0.235911
# 2  1966-01-01         1  1966   January  0.482511      0.222805
# 3  1966-01-01         1  1966   January  0.482511      0.222805
# 4  1966-01-01         1  1966   January  0.509814      0.301442

# %%
# check for any duplicacy in the dataset (0: no duplicates)

train_data.duplicated(subset=None, keep='first').sum()
# Out:
# 0

# %%
# remove the useless attributes from the dataset 

# store unique state_name and diseases for label encoding (dont drop them!)
states = np.asarray(train_data.state_name.unique())
#dis = np.unique(train_data['disease'].values)

week       = train_data.pop('week')
monthN     = train_data.pop('MonthName')
LOW        = train_data.pop('LastDayWeek')
state     = train_data.pop('state')
train_data.head()
# Out:
#   state_name      disease  cases  incidence_per_capita  MonthMax  Year  \
# 0    alabama  HEPATITIS A      5                  0.14         1  1966
# 1    alabama      RUBELLA      7                  0.20         1  1966
# 2   arkansas  HEPATITIS A     11                  0.58         1  1966
# 3   arkansas      MEASLES      2                  0.11         1  1966
# 4    arizona  HEPATITIS A      6                  0.37         1  1966
#
#       t_avg  tavg_anomaly
# 0  0.536052      0.235911
# 1  0.536052      0.235911
# 2  0.482511      0.222805
# 3  0.482511      0.222805
# 4  0.509814      0.301442

# %%
# Create test_train splits

from sklearn.model_selection import train_test_split as tts

y = train_data.pop('disease')
train, test, y_train, y_test = tts(train_data, y,test_size = 0.4)

# %%
print (train.shape)
print (y_train.shape)

print (test.shape)
print (y_test.shape)
# Out:
# (3078, 7)
# (3078,)
# (2052, 7)
# (2052,)

# %%
# examine the test/train data now (uncomment the one you want to examine)

train.describe()
#test.describe()
# Out:
#              cases  incidence_per_capita  MonthMax         Year        t_avg  \
# count  3078.000000           3078.000000    3078.0  3078.000000  3078.000000
# mean     26.285900              0.968726       1.0  1976.800845     0.671973
# std      77.389468              3.385480       0.0    11.242372     0.182948
# min       1.000000              0.000000       1.0  1960.000000     0.028992
# 25%       2.000000              0.060000       1.0  1969.000000     0.533596
# 50%       5.000000              0.180000       1.0  1974.000000     0.686191
# 75%      19.000000              0.560000       1.0  1982.000000     0.833795
# max    1540.000000             75.860000       1.0  2011.000000     0.990966
#
#        tavg_anomaly
# count   3078.000000
# mean       0.244941
# std        0.115559
# min        0.000000
# 25%        0.165138
# 50%        0.228047
# 75%        0.302752
# max        1.000000

# %%
# label encoding of useful non-numerical attributes

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y)

y_train = le.transform(y_train)
y_test = le.transform(y_test)

le2 = LabelEncoder()
le2.fit(states)

train['state_name'] = le2.transform(train.state_name)
test['state_name'] = le2.transform(test.state_name)

# %%
# check dtypes of each attribute (numst be numerical)

train.head()
# Out:
#       state_name  cases  incidence_per_capita  MonthMax  Year     t_avg  \
# 680           48     32                  1.83         1  1969  0.668803
# 708           11     10                  1.33         1  1969  0.871766
# 4781          24      4                  0.16         1  1980  0.855921
# 386           44      5                  0.49         1  1967  0.858528
# 896           30     12                  0.16         1  1970  0.493436
#
#       tavg_anomaly
# 680       0.277851
# 708       0.180865
# 4781      0.153342
# 386       0.521625
# 896       0.297510

# %%
#model training (try to load few classifiers for examining performance and chose the best)

from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.naive_bayes import MultinomialNB as MNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis, LinearDiscriminantAnalysis

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

classifiers=[
    (LogisticRegression(penalty='l1'),"LR"),
    (KNeighborsClassifier(n_neighbors=3, weights='distance', algorithm = 'auto'),"KNC"),
    (SVC(),'SVC'),
    (QuadraticDiscriminantAnalysis(),'QDA'),
    (RandomForestClassifier(max_depth=50, n_estimators=10, max_features=1),'RFC'),
    (AdaBoostClassifier(),'ADC'),
    (SGDClassifier(),'SGDC'),
    (DecisionTreeClassifier(max_depth=5),'DTC'),
    (LinearDiscriminantAnalysis(),'LDA'),
    (MNB(), 'MNB')
]

eval_ =[]
train_acc, test_acc, name = [], [], []
f1_, rec_, prec_ = [], [], []
for clf in classifiers:
    print ("training...%s",clf[1])
    clf[0].fit(train, y_train)
    y_preds = clf[0].predict(test)
    y_preds_train = clf[0].predict(train)
    name.append(clf[1])
    train_acc.append( accuracy_score(y_train, y_preds_train)*100 )
    test_acc.append( accuracy_score(y_test, y_preds)*100 )
    f1_.append( f1_score(y_test, y_preds, average='macro')*100 )
    rec_.append( recall_score(y_test, y_preds, average='macro')*100 )
    prec_.append( precision_score(y_test, y_preds, average='macro')*100 )
    print (clf[1])
    print ("testing_accuracy", accuracy_score(y_test, y_preds)*100)
    print ("training_accuracy", accuracy_score(y_train, y_preds_train)*100)
    print ("precision_test: ", precision_score(y_test, y_preds, average='macro')*100)
    print ("f1_score: ", f1_score(y_test, y_preds, average='macro')*100)
    print ("recall_score: ", recall_score(y_test, y_preds, average='macro')*100)
eval_.append(train_acc)
eval_.append(test_acc)
eval_.append(f1_)
eval_.append(rec_)
eval_.append(prec_)
# Out:
# training...%s LR
# LR
# testing_accuracy 38.7914230019
# training_accuracy 40.1884340481
# precision_test:  15.0226817313
# f1_score:  15.8660635217
# recall_score:  21.7657461265
# training...%s KNC
# KNC
# testing_accuracy 39.9122807018
# training_accuracy 96.4262508122
# precision_test:  41.2891711583
# f1_score:  40.1037639245
# recall_score:  39.3213538749
# training...%s SVC
# SVC
# testing_accuracy 42.3001949318
# training_accuracy 72.7745289149
# precision_test:  42.84939703
# f1_score:  36.1712032036
# recall_score:  34.5987536556
# training...%s QDA
# QDA
# testing_accuracy 26.6081871345
# training_accuracy 26.2833008447
# precision_test:  38.3235465594
# f1_score:  22.2305917203
# recall_score:  24.0412520365
# training...%s RFC
# RFC
# testing_accuracy 39.7173489279
# training_accuracy 95.0617283951
# precision_test:  40.9636950358
# f1_score:  37.6671815284
# recall_score:  36.0376899841
# training...%s ADC
# ADC
# testing_accuracy 42.9824561404
# training_accuracy 44.1520467836
# precision_test:  34.1252737699
# f1_score:  27.9969055269
# recall_score:  28.4405594984
# training...%s SGDC
# SGDC
# testing_accuracy 21.5886939571
# training_accuracy 22.6770630279
# precision_test:  3.59811565952
# f1_score:  5.91850367401
# recall_score:  16.6666666667
# training...%s DTC
# DTC
# testing_accuracy 49.3177387914
# training_accuracy 50.9421702404
# precision_test:  54.2057579728
# f1_score:  45.1697098733
# recall_score:  44.9887764381
# training...%s LDA
# LDA
# testing_accuracy 40.4970760234
# training_accuracy 41.3905133203
# precision_test:  27.2196267137
# f1_score:  26.1876763462
# recall_score:  29.8058391218
# training...%s MNB
# MNB
# testing_accuracy 24.6588693957
# training_accuracy 26.0883690708
# precision_test:  24.7477681917
# f1_score:  19.7246317124
# recall_score:  25.5397143986

# %%
from matplotlib import pyplot as plt

titles = ['train_accuracy', 'test_accuracy', 'f1_score', 'recall', 'precision']

for i in range(len(eval_)):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    A = eval_[i][:]
    plt.title(titles[i])
    plt.plot(A)
    for j, label in enumerate(name):
        plt.text(j,A[j], label) 
    plt.show()

# %%
# using plotly for the beautiful plots 

import plotly.plotly as py
import plotly
import pandas as pd

# login api for plotly (dont forget to sign up to plotly)
plotly.tools.set_credentials_file(username= 'Ubaid01', api_key = "ip2KAG3NXA4zbbzIzbzY")

# %%
# for UI

import pandas as pd 
import numpy as np
import plotly.offline as py

def get_viz(the_yr_data, yr):
    py.init_notebook_mode(connected=True)


    for col in the_yr_data.columns:
        the_yr_data[col] = the_yr_data[col].astype(str)

    
    scl = [
            # Let first 10% (0.1) of the values have color rgb(0, 0, 0)
            [0, 'rgb(0, 0, 0)'],
            [0.1, 'rgb(0, 0, 0)'],

            # Let values between 10-20% of the min and max of z
            # have color rgb(20, 20, 20)
            [0.1, 'rgb(20, 20, 20)'],
            [0.2, 'rgb(20, 20, 20)'],

            # Values between 20-30% of the min and max of z
            # have color rgb(40, 40, 40)
            [0.2, 'rgb(40, 40, 40)'],
            [0.3, 'rgb(40, 40, 40)'],

            [0.3, 'rgb(60, 60, 60)'],
            [0.4, 'rgb(60, 60, 60)'],

            [0.4, 'rgb(80, 80, 80)'],
            [0.5, 'rgb(80, 80, 80)'],

            [0.5, 'rgb(100, 100, 100)'],
            [0.6, 'rgb(100, 100, 100)'],

            [0.6, 'rgb(120, 120, 120)'],
            [0.7, 'rgb(120, 120, 120)'],

            [0.7, 'rgb(140, 140, 140)'],
            [0.8, 'rgb(140, 140, 140)'],

            [0.8, 'rgb(160, 160, 160)'],
            [0.9, 'rgb(160, 160, 160)'],

            [0.9, 'rgb(180, 180, 180)'],
            [1.0, 'rgb(180, 180, 180)']
        ]
    data = [ dict(
            type='choropleth',
            colorscale = scl,
            autocolorscale = True,
            locations = the_yr_data['state'],
            z = the_yr_data['cases'].astype(float),
            zmin=0,
            zmax=500,
            locationmode = 'USA-states',
            text = the_yr_data['text'],
            marker = dict(
                line = dict (
                    color = 'rgb(255,255,255)',
                    width = 2
                )
            ),
            colorbar = dict(
                title = "Disease outbreak - cases in %d" %(yr)
            )
        ) ]

    layout = dict(
        title = '%d US Diseases Cases Found by State<br>(Hover for breakdown)' %(yr),
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
            ),
    )

    fig = dict( data=data, layout=layout )

    url = py.iplot( fig, validate=False)

def get_1yr_viz(yr):
    data = pd.read_csv('for_visulisation.csv')
    the_yr_data = data.loc[data['Year'] ==yr]
    the_yr_data.head()
    from collections import defaultdict
    har = defaultdict(set)
    a = list(the_yr_data.state_name)
    b = list(the_yr_data.disease)
    for i in range(len(a)):
        har[a[i]].add(b[i])
    print(len(a),len(b))
    the_yr_data['disease_all'] = [' '.join(list(har[i])) for i in the_yr_data.state_name]
    the_yr_data['text'] = the_yr_data['state_name'] + '<br>' +\
    'Disease '+the_yr_data['disease_all']
    
    tf = the_yr_data.filter(['state_name','state','cases'], axis=1)
    tf.cases = tf.cases.astype(int)
    the_yr_data_2 = tf.groupby(['state_name','state']).sum().reset_index()
    the_yr_data_2['disease_all'] = [' '.join(list(har[i])) for i in the_yr_data_2.state_name]
    the_yr_data_2['text'] = the_yr_data_2['state_name'] + '<br>' +\
    'Disease '+the_yr_data_2['disease_all']
    
    get_viz(the_yr_data_2, yr)

# %%
 #get visualization for any year

get_1yr_viz(1977)
# Out:
# 9816 9816
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="d4edc8cd-5a21-40f3-b91d-56ca85d2f753" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d4edc8cd-5a21-40f3-b91d-56ca85d2f753", [{"type": "choropleth", "colorscale": [[0, "rgb(0, 0, 0)"], [0.1, "rgb(0, 0, 0)"], [0.1, "rgb(20, 20, 20)"], [0.2, "rgb(20, 20, 20)"], [0.2, "rgb(40, 40, 40)"], [0.3, "rgb(40, 40, 40)"], [0.3, "rgb(60, 60, 60)"], [0.4, "rgb(60, 60, 60)"], [0.4, "rgb(80, 80, 80)"], [0.5, "rgb(80, 80, 80)"], [0.5, "rgb(100, 100, 100)"], [0.6, "rgb(100, 100, 100)"], [0.6, "rgb(120, 120, 120)"], [0.7, "rgb(120, 120, 120)"], [0.7, "rgb(140, 140, 140)"], [0.8, "rgb(140, 140, 140)"], [0.8, "rgb(160, 160, 160)"], [0.9, "rgb(160, 160, 160)"], [0.9, "rgb(180, 180, 180)"], [1.0, "rgb(180, 180, 180)"]], "autocolorscale": true, "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "DC", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "z": [686.0, 652.0, 1196.0, 629.0, 15527.0, 1548.0, 1762.0, 237.0, 55.0, 2259.0, 2077.0, 435.0, 471.0, 4834.0, 5586.0, 5415.0, 3404.0, 1876.0, 720.0, 376.0, 839.0, 1435.0, 6286.0, 3265.0, 579.0, 3102.0, 1211.0, 476.0, 113.0, 575.0, 2700.0, 684.0, 10623.0, 1034.0, 138.0, 4971.0, 1039.0, 1879.0, 4971.0, 379.0, 524.0, 189.0, 4066.0, 5822.0, 389.0, 371.0, 3779.0, 1891.0, 1031.0, 5121.0, 55.0], "zmin": 0, "zmax": 500, "locationmode": "USA-states", "text": ["ALABAMA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "ALASKA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "ARIZONA<br>Disease HEPATITIS A MEASLES RUBELLA", "ARKANSAS<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "CALIFORNIA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "COLORADO<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "CONNECTICUT<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "DELAWARE<br>Disease HEPATITIS A MEASLES RUBELLA MUMPS", "DISTRICT OF COLUMBIA<br>Disease HEPATITIS A PERTUSSIS MEASLES MUMPS", "FLORIDA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "GEORGIA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "HAWAII<br>Disease HEPATITIS A MEASLES RUBELLA MUMPS", "IDAHO<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "ILLINOIS<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "INDIANA<br>Disease HEPATITIS A MEASLES RUBELLA MUMPS", "IOWA<br>Disease HEPATITIS A MEASLES RUBELLA MUMPS", "KANSAS<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "KENTUCKY<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "LOUISIANA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "MAINE<br>Disease HEPATITIS A MEASLES RUBELLA MUMPS", "MARYLAND<br>Disease HEPATITIS A MEASLES RUBELLA MUMPS", "MASSACHUSETTS<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "MICHIGAN<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "MINNESOTA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "MISSISSIPPI<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "MISSOURI<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "MONTANA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "NEBRASKA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "NEVADA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "NEW HAMPSHIRE<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "NEW JERSEY<br>Disease HEPATITIS A MEASLES RUBELLA MUMPS", "NEW MEXICO<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "NEW YORK<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "NORTH CAROLINA<br>Disease PERTUSSIS RUBELLA MEASLES MUMPS HEPATITIS A", "NORTH DAKOTA<br>Disease HEPATITIS A MEASLES RUBELLA MUMPS", "OHIO<br>Disease PERTUSSIS RUBE ...
